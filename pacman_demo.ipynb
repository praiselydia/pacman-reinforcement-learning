# %% [markdown]
# ### CSCN8020 – Reinforcement Learning Programming
#
# #### Group No: 8
#
# #### Group Members:
# * Praiselin Lydia Gladston - 8959325
#
# * Sudharsan Tirumal - 8977532
#
# ### Title: "Implementation of Pac-Man using Reinforcement Learning"

# %%
pip install  torch torchvision stable-baselines3
# Out:
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# Requirement already satisfied: torch in /opt/homebrew/lib/python3.9/site-packages (2.4.0)
# Requirement already satisfied: torchvision in /opt/homebrew/lib/python3.9/site-packages (0.19.0)
# Requirement already satisfied: stable-baselines3 in /opt/homebrew/lib/python3.9/site-packages (2.3.2)
# Requirement already satisfied: filelock in /opt/homebrew/lib/python3.9/site-packages (from torch) (3.15.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in /Users/jothikaravichandran/Library/Python/3.9/lib/python/site-packages (from torch) (4.12.2)
# Requirement already satisfied: sympy in /opt/homebrew/lib/python3.9/site-packages (from torch) (1.13.1)
# Requirement already satisfied: networkx in /opt/homebrew/lib/python3.9/site-packages (from torch) (3.2.1)
# Requirement already satisfied: jinja2 in /opt/homebrew/lib/python3.9/site-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in /opt/homebrew/lib/python3.9/site-packages (from torch) (2024.6.1)
# Requirement already satisfied: numpy in /opt/homebrew/lib/python3.9/site-packages (from torchvision) (2.0.1)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /opt/homebrew/lib/python3.9/site-packages (from torchvision) (10.4.0)
# Requirement already satisfied: gymnasium<0.30,>=0.28.1 in /opt/homebrew/lib/python3.9/site-packages (from stable-baselines3) (0.29.1)
# Requirement already satisfied: cloudpickle in /opt/homebrew/lib/python3.9/site-packages (from stable-baselines3) (3.0.0)
# Requirement already satisfied: pandas in /opt/homebrew/lib/python3.9/site-packages (from stable-baselines3) (2.2.2)
# Requirement already satisfied: matplotlib in /opt/homebrew/lib/python3.9/site-packages (from stable-baselines3) (3.9.1.post1)
# Requirement already satisfied: farama-notifications>=0.0.1 in /opt/homebrew/lib/python3.9/site-packages (from gymnasium<0.30,>=0.28.1->stable-baselines3) (0.0.4)
# Requirement already satisfied: importlib-metadata>=4.8.0 in /Users/jothikaravichandran/Library/Python/3.9/lib/python/site-packages (from gymnasium<0.30,>=0.28.1->stable-baselines3) (8.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/homebrew/lib/python3.9/site-packages (from jinja2->torch) (2.1.5)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/homebrew/lib/python3.9/site-packages (from matplotlib->stable-baselines3) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /opt/homebrew/lib/python3.9/site-packages (from matplotlib->stable-baselines3) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/homebrew/lib/python3.9/site-packages (from matplotlib->stable-baselines3) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/homebrew/lib/python3.9/site-packages (from matplotlib->stable-baselines3) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /Users/jothikaravichandran/Library/Python/3.9/lib/python/site-packages (from matplotlib->stable-baselines3) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/homebrew/lib/python3.9/site-packages (from matplotlib->stable-baselines3) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/jothikaravichandran/Library/Python/3.9/lib/python/site-packages (from matplotlib->stable-baselines3) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /opt/homebrew/lib/python3.9/site-packages (from matplotlib->stable-baselines3) (6.4.0)
# Requirement already satisfied: pytz>=2020.1 in /opt/homebrew/lib/python3.9/site-packages (from pandas->stable-baselines3) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/homebrew/lib/python3.9/site-packages (from pandas->stable-baselines3) (2024.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/homebrew/lib/python3.9/site-packages (from sympy->torch) (1.3.0)
# Requirement already satisfied: zipp>=0.5 in /Users/jothikaravichandran/Library/Python/3.9/lib/python/site-packages (from importlib-metadata>=4.8.0->gymnasium<0.30,>=0.28.1->stable-baselines3) (3.19.2)
# Requirement already satisfied: six>=1.5 in /Users/jothikaravichandran/Library/Python/3.9/lib/python/site-packages (from python-dateutil>=2.7->matplotlib->stable-baselines3) (1.16.0)
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#
# [notice] A new release of pip is available: 24.1.2 -> 24.2
# [notice] To update, run: python3.9 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install gym==0.25.2
# Out:
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# Collecting gym==0.25.2
#   Using cached gym-0.25.2.tar.gz (734 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: numpy>=1.18.0 in /opt/homebrew/lib/python3.9/site-packages (from gym==0.25.2) (2.0.1)
# Requirement already satisfied: cloudpickle>=1.2.0 in /opt/homebrew/lib/python3.9/site-packages (from gym==0.25.2) (3.0.0)
# Requirement already satisfied: gym-notices>=0.0.4 in /opt/homebrew/lib/python3.9/site-packages (from gym==0.25.2) (0.0.8)
# Requirement already satisfied: importlib-metadata>=4.8.0 in /Users/jothikaravichandran/Library/Python/3.9/lib/python/site-packages (from gym==0.25.2) (8.2.0)
# Requirement already satisfied: zipp>=0.5 in /Users/jothikaravichandran/Library/Python/3.9/lib/python/site-packages (from importlib-metadata>=4.8.0->gym==0.25.2) (3.19.2)
# Building wheels for collected packages: gym
#   Building wheel for gym (pyproject.toml) ... done
#   Created wheel for gym: filename=gym-0.25.2-py3-none-any.whl size=852284 sha256=42d4102a92ff1e2a6c78f033af6ae2091a080b772a1846d2e618ffe3f55308bb
#   Stored in directory: /Users/jothikaravichandran/Library/Caches/pip/wheels/05/4d/6c/d0ef0db36695ce032fe20099e3149d8db85cf36656176ff745
# Successfully built gym
# Installing collected packages: gym
#   Attempting uninstall: gym
#     Found existing installation: gym 0.26.2
#     Uninstalling gym-0.26.2:
#       Successfully uninstalled gym-0.26.2
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# Successfully installed gym-0.25.2
#
# [notice] A new release of pip is available: 24.1.2 -> 24.2
# [notice] To update, run: python3.9 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install ipykernel
# Out:
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/pty.py:95: DeprecationWarning: This process (pid=31135) is multi-threaded, use of forkpty() may lead to deadlocks in the child.
#   pid, fd = os.forkpty()
# Requirement already satisfied: ipykernel in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (6.29.5)
# Requirement already satisfied: appnope in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from ipykernel) (0.1.4)
# Requirement already satisfied: comm>=0.1.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from ipykernel) (0.2.2)
# Requirement already satisfied: debugpy>=1.6.5 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from ipykernel) (1.8.2)
# Requirement already satisfied: ipython>=7.23.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from ipykernel) (8.26.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from ipykernel) (8.6.2)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from ipykernel) (5.7.2)
# Requirement already satisfied: matplotlib-inline>=0.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from ipykernel) (0.1.7)
# Requirement already satisfied: nest-asyncio in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from ipykernel) (1.6.0)
# Requirement already satisfied: packaging in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from ipykernel) (24.1)
# Requirement already satisfied: psutil in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from ipykernel) (6.0.0)
# Requirement already satisfied: pyzmq>=24 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from ipykernel) (26.0.3)
# Requirement already satisfied: tornado>=6.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from ipykernel) (6.4.1)
# Requirement already satisfied: traitlets>=5.4.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from ipykernel) (5.14.3)
# Requirement already satisfied: decorator in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel) (0.19.1)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel) (3.0.47)
# Requirement already satisfied: pygments>=2.4.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel) (2.18.0)
# Requirement already satisfied: stack-data in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel) (0.6.3)
# Requirement already satisfied: pexpect>4.3 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel) (4.9.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from jupyter-client>=6.1.12->ipykernel) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel) (4.2.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel) (0.7.0)
# Requirement already satisfied: wcwidth in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel) (0.2.13)
# Requirement already satisfied: six>=1.5 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from python-dateutil>=2.8.2->jupyter-client>=6.1.12->ipykernel) (1.16.0)
# Requirement already satisfied: executing>=1.2.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from stack-data->ipython>=7.23.1->ipykernel) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from stack-data->ipython>=7.23.1->ipykernel) (2.4.1)
# Requirement already satisfied: pure-eval in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from stack-data->ipython>=7.23.1->ipykernel) (0.2.3)
#
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install gym\[atari\]
# Out:
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# Requirement already satisfied: gym[atari] in /opt/homebrew/lib/python3.9/site-packages (0.25.2)
# Requirement already satisfied: numpy>=1.18.0 in /opt/homebrew/lib/python3.9/site-packages (from gym[atari]) (2.0.1)
# Requirement already satisfied: cloudpickle>=1.2.0 in /opt/homebrew/lib/python3.9/site-packages (from gym[atari]) (3.0.0)
# Requirement already satisfied: gym-notices>=0.0.4 in /opt/homebrew/lib/python3.9/site-packages (from gym[atari]) (0.0.8)
# Requirement already satisfied: importlib-metadata>=4.8.0 in /Users/jothikaravichandran/Library/Python/3.9/lib/python/site-packages (from gym[atari]) (8.2.0)
# Collecting ale-py~=0.7.5 (from gym[atari])
#   Downloading ale_py-0.7.5-cp39-cp39-macosx_11_0_arm64.whl.metadata (8.1 kB)
# Requirement already satisfied: importlib-resources in /opt/homebrew/lib/python3.9/site-packages (from ale-py~=0.7.5->gym[atari]) (6.4.0)
# Requirement already satisfied: zipp>=0.5 in /Users/jothikaravichandran/Library/Python/3.9/lib/python/site-packages (from importlib-metadata>=4.8.0->gym[atari]) (3.19.2)
# Downloading ale_py-0.7.5-cp39-cp39-macosx_11_0_arm64.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 2.6 MB/s eta 0:00:0000:0100:01
# Installing collected packages: ale-py
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# Successfully installed ale-py-0.7.5
#
# [notice] A new release of pip is available: 24.1.2 -> 24.2
# [notice] To update, run: python3.9 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# pip install gym[accept-rom-license]
# %pip install "gym[accept-rom-license]"
# Out:
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# Requirement already satisfied: gym[accept-rom-license] in /opt/homebrew/lib/python3.9/site-packages (0.25.2)
# Requirement already satisfied: numpy>=1.18.0 in /opt/homebrew/lib/python3.9/site-packages (from gym[accept-rom-license]) (2.0.1)
# Requirement already satisfied: cloudpickle>=1.2.0 in /opt/homebrew/lib/python3.9/site-packages (from gym[accept-rom-license]) (3.0.0)
# Requirement already satisfied: gym-notices>=0.0.4 in /opt/homebrew/lib/python3.9/site-packages (from gym[accept-rom-license]) (0.0.8)
# Requirement already satisfied: importlib-metadata>=4.8.0 in /Users/jothikaravichandran/Library/Python/3.9/lib/python/site-packages (from gym[accept-rom-license]) (8.2.0)
# Collecting autorom~=0.4.2 (from autorom[accept-rom-license]~=0.4.2; extra == "accept-rom-license"->gym[accept-rom-license])
#   Using cached AutoROM-0.4.2-py3-none-any.whl.metadata (2.8 kB)
# Collecting click (from autorom~=0.4.2->autorom[accept-rom-license]~=0.4.2; extra == "accept-rom-license"->gym[accept-rom-license])
#   Using cached click-8.1.7-py3-none-any.whl.metadata (3.0 kB)
# Collecting requests (from autorom~=0.4.2->autorom[accept-rom-license]~=0.4.2; extra == "accept-rom-license"->gym[accept-rom-license])
#   Using cached requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Collecting tqdm (from autorom~=0.4.2->autorom[accept-rom-license]~=0.4.2; extra == "accept-rom-license"->gym[accept-rom-license])
#   Using cached tqdm-4.66.5-py3-none-any.whl.metadata (57 kB)
# Collecting AutoROM.accept-rom-license (from autorom[accept-rom-license]~=0.4.2; extra == "accept-rom-license"->gym[accept-rom-license])
#   Using cached AutoROM.accept-rom-license-0.6.1.tar.gz (434 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: zipp>=0.5 in /Users/jothikaravichandran/Library/Python/3.9/lib/python/site-packages (from importlib-metadata>=4.8.0->gym[accept-rom-license]) (3.19.2)
# Collecting charset-normalizer<4,>=2 (from requests->autorom~=0.4.2->autorom[accept-rom-license]~=0.4.2; extra == "accept-rom-license"->gym[accept-rom-license])
#   Using cached charset_normalizer-3.3.2-cp39-cp39-macosx_11_0_arm64.whl.metadata (33 kB)
# Collecting idna<4,>=2.5 (from requests->autorom~=0.4.2->autorom[accept-rom-license]~=0.4.2; extra == "accept-rom-license"->gym[accept-rom-license])
#   Using cached idna-3.7-py3-none-any.whl.metadata (9.9 kB)
# Collecting urllib3<3,>=1.21.1 (from requests->autorom~=0.4.2->autorom[accept-rom-license]~=0.4.2; extra == "accept-rom-license"->gym[accept-rom-license])
#   Using cached urllib3-2.2.2-py3-none-any.whl.metadata (6.4 kB)
# Collecting certifi>=2017.4.17 (from requests->autorom~=0.4.2->autorom[accept-rom-license]~=0.4.2; extra == "accept-rom-license"->gym[accept-rom-license])
#   Using cached certifi-2024.7.4-py3-none-any.whl.metadata (2.2 kB)
# Using cached AutoROM-0.4.2-py3-none-any.whl (16 kB)
# Using cached click-8.1.7-py3-none-any.whl (97 kB)
# Using cached requests-2.32.3-py3-none-any.whl (64 kB)
# Using cached tqdm-4.66.5-py3-none-any.whl (78 kB)
# Using cached certifi-2024.7.4-py3-none-any.whl (162 kB)
# Using cached charset_normalizer-3.3.2-cp39-cp39-macosx_11_0_arm64.whl (120 kB)
# Using cached idna-3.7-py3-none-any.whl (66 kB)
# Using cached urllib3-2.2.2-py3-none-any.whl (121 kB)
# Building wheels for collected packages: AutoROM.accept-rom-license
#   Building wheel for AutoROM.accept-rom-license (pyproject.toml) ... done
#   Created wheel for AutoROM.accept-rom-license: filename=AutoROM.accept_rom_license-0.6.1-py3-none-any.whl size=446662 sha256=f62f8f5ebc53b51f0152b88fb193f6d71ce7c19a3a17ee641e464905059bf8db
#   Stored in directory: /Users/jothikaravichandran/Library/Caches/pip/wheels/b1/1f/f7/2da07cf4f81ea264bdaf043028749d88fe0c2227134a22cf80
# Successfully built AutoROM.accept-rom-license
# Installing collected packages: urllib3, tqdm, idna, click, charset-normalizer, certifi, requests, AutoROM.accept-rom-license, autorom
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# Successfully installed AutoROM.accept-rom-license-0.6.1 autorom-0.4.2 certifi-2024.7.4 charset-normalizer-3.3.2 click-8.1.7 idna-3.7 requests-2.32.3 tqdm-4.66.5 urllib3-2.2.2
#
# [notice] A new release of pip is available: 24.1.2 -> 24.2
# [notice] To update, run: python3.9 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# pip install gym[ale]
# %pip install "gym[ale]"
# Out:
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# Requirement already satisfied: gym[ale] in /opt/homebrew/lib/python3.9/site-packages (0.25.2)
# WARNING: gym 0.25.2 does not provide the extra 'ale'
# Requirement already satisfied: numpy>=1.18.0 in /opt/homebrew/lib/python3.9/site-packages (from gym[ale]) (2.0.1)
# Requirement already satisfied: cloudpickle>=1.2.0 in /opt/homebrew/lib/python3.9/site-packages (from gym[ale]) (3.0.0)
# Requirement already satisfied: gym-notices>=0.0.4 in /opt/homebrew/lib/python3.9/site-packages (from gym[ale]) (0.0.8)
# Requirement already satisfied: importlib-metadata>=4.8.0 in /Users/jothikaravichandran/Library/Python/3.9/lib/python/site-packages (from gym[ale]) (8.2.0)
# Requirement already satisfied: zipp>=0.5 in /Users/jothikaravichandran/Library/Python/3.9/lib/python/site-packages (from importlib-metadata>=4.8.0->gym[ale]) (3.19.2)
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#
# [notice] A new release of pip is available: 24.1.2 -> 24.2
# [notice] To update, run: python3.9 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# apt-get install -y xvfb ffmpeg


# !brew install ffmpeg
# Out:
# ==> Auto-updating Homebrew...
# Adjust how often this is run with HOMEBREW_AUTO_UPDATE_SECS or disable with
# HOMEBREW_NO_AUTO_UPDATE. Hide these hints with HOMEBREW_NO_ENV_HINTS (see `man brew`).
# ==> Downloading https://ghcr.io/v2/homebrew/portable-ruby/portable-ruby/blobs/sha256:ce5c135bf98da783bf5964e89aab587e3341c8adc379f36ace17ae7881f53e8c
# ######################################################################### 100.0%                         0.8% 62.0%
# ==> Pouring portable-ruby-3.3.4_1.arm64_big_sur.bottle.tar.gz
# ==> Auto-updated Homebrew!
# Updated 2 taps (homebrew/core and homebrew/cask).
# ==> New Formulae
# aider                      libmps                     progressline
# clangql                    libxpresent                safety
# golangci-lint-langserver   mysql-client@8.4           sq
# kubehound                  mysql@8.4                  stellar-cli
# libassuan@2                onion-location             tabiew
# libgedit-gfls              oxker                      usage
# ==> New Casks
# bbackupp                   find-my-ports              pearcleaner
# cables                     font-satoshi               zipic
# cork                       meta-quest-developer-hub
#
# ==> Downloading https://ghcr.io/v2/homebrew/core/ffmpeg/manifests/7.0.2
# ######################################################################### 100.0%
# ==> Fetching dependencies for ffmpeg: brotli, giflib, highway, imath, jpeg-turbo, libpng, lz4, zstd, libtiff, little-cms2, openexr, webp, jpeg-xl, libvmaf, aom, aribb24, dav1d, freetype, fontconfig, frei0r, gmp, libunistring, libidn2, libtasn1, nettle, p11-kit, libevent, libnghttp2, unbound, gnutls, python@3.12, glib, xorgproto, libxau, libxdmcp, libxcb, libx11, libxext, libxrender, lzo, pixman, cairo, graphite2, icu4c, harfbuzz, lame, fribidi, libunibreak, libass, libbluray, cjson, libmicrohttpd, mbedtls, librist, libsoxr, libssh, libvidstab, libogg, libvorbis, libvpx, opencore-amr, openjpeg, opus, rav1e, libsamplerate, flac, mpg123, libsndfile, rubberband, sdl2, snappy, speex, srt, svt-av1, leptonica, libb2, libarchive, pango, tesseract, theora, x264, x265, xvid, libsodium, zeromq and zimg
# ==> Downloading https://ghcr.io/v2/homebrew/core/brotli/manifests/1.1.0-1
# ######################################################################### 100.0%
# ==> Fetching brotli
# ==> Downloading https://ghcr.io/v2/homebrew/core/brotli/blobs/sha256:2a95140d611
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/giflib/manifests/5.2.2
# ######################################################################### 100.0%
# ==> Fetching giflib
# ==> Downloading https://ghcr.io/v2/homebrew/core/giflib/blobs/sha256:c6b05aecad0
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/highway/manifests/1.2.0
# ######################################################################### 100.0%
# ==> Fetching highway
# ==> Downloading https://ghcr.io/v2/homebrew/core/highway/blobs/sha256:406c96cf28
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/imath/manifests/3.1.11
# ######################################################################### 100.0%
# ==> Fetching imath
# ==> Downloading https://ghcr.io/v2/homebrew/core/imath/blobs/sha256:9cffec79d68d
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/jpeg-turbo/manifests/3.0.3
# ######################################################################### 100.0%
# ==> Fetching jpeg-turbo
# ==> Downloading https://ghcr.io/v2/homebrew/core/jpeg-turbo/blobs/sha256:9ea4229
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libpng/manifests/1.6.43
# ######################################################################### 100.0%
# ==> Fetching libpng
# ==> Downloading https://ghcr.io/v2/homebrew/core/libpng/blobs/sha256:37936ba5cd5
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/lz4/manifests/1.9.4
# ######################################################################### 100.0%
# ==> Fetching lz4
# ==> Downloading https://ghcr.io/v2/homebrew/core/lz4/blobs/sha256:5a8b7116d978e4
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/zstd/manifests/1.5.6
# ######################################################################### 100.0%
# ==> Fetching zstd
# ==> Downloading https://ghcr.io/v2/homebrew/core/zstd/blobs/sha256:2028141683f55
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libtiff/manifests/4.6.0
# ######################################################################### 100.0%
# ==> Fetching libtiff
# ==> Downloading https://ghcr.io/v2/homebrew/core/libtiff/blobs/sha256:a9cafbce08
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/little-cms2/manifests/2.16
# ######################################################################### 100.0%
# ==> Fetching little-cms2
# ==> Downloading https://ghcr.io/v2/homebrew/core/little-cms2/blobs/sha256:d1ed57
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/openexr/manifests/3.2.4
# ######################################################################### 100.0%
# ==> Fetching openexr
# ==> Downloading https://ghcr.io/v2/homebrew/core/openexr/blobs/sha256:49b4acf727
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/webp/manifests/1.4.0
# ######################################################################### 100.0%
# ==> Fetching webp
# ==> Downloading https://ghcr.io/v2/homebrew/core/webp/blobs/sha256:1ba924051fcd6
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/jpeg-xl/manifests/0.10.3
# ######################################################################### 100.0%
# ==> Fetching jpeg-xl
# ==> Downloading https://ghcr.io/v2/homebrew/core/jpeg-xl/blobs/sha256:00d633fdbc
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libvmaf/manifests/3.0.0
# ######################################################################### 100.0%
# ==> Fetching libvmaf
# ==> Downloading https://ghcr.io/v2/homebrew/core/libvmaf/blobs/sha256:bdc90ebc17
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/aom/manifests/3.9.1
# ######################################################################### 100.0%
# ==> Fetching aom
# ==> Downloading https://ghcr.io/v2/homebrew/core/aom/blobs/sha256:8cb9a41dca274a
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/aribb24/manifests/1.0.4
# ######################################################################### 100.0%
# ==> Fetching aribb24
# ==> Downloading https://ghcr.io/v2/homebrew/core/aribb24/blobs/sha256:00fe805d46
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/dav1d/manifests/1.4.3
# ######################################################################### 100.0%
# ==> Fetching dav1d
# ==> Downloading https://ghcr.io/v2/homebrew/core/dav1d/blobs/sha256:a8796b7771db
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/freetype/manifests/2.13.2-1
# ######################################################################### 100.0%
# ==> Fetching freetype
# ==> Downloading https://ghcr.io/v2/homebrew/core/freetype/blobs/sha256:8966d4448
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/fontconfig/manifests/2.15.0
# ######################################################################### 100.0%
# ==> Fetching fontconfig
# ==> Downloading https://ghcr.io/v2/homebrew/core/fontconfig/blobs/sha256:4732e8c
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/frei0r/manifests/2.3.3
# ######################################################################### 100.0%
# ==> Fetching frei0r
# ==> Downloading https://ghcr.io/v2/homebrew/core/frei0r/blobs/sha256:59d88950f34
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/gmp/manifests/6.3.0
# ######################################################################### 100.0%
# ==> Fetching gmp
# ==> Downloading https://ghcr.io/v2/homebrew/core/gmp/blobs/sha256:78e4f40cba6419
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libunistring/manifests/1.2
# ######################################################################### 100.0%
# ==> Fetching libunistring
# ==> Downloading https://ghcr.io/v2/homebrew/core/libunistring/blobs/sha256:4a1c0
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libidn2/manifests/2.3.7
# ######################################################################### 100.0%
# ==> Fetching libidn2
# ==> Downloading https://ghcr.io/v2/homebrew/core/libidn2/blobs/sha256:670f6ed376
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libtasn1/manifests/4.19.0
# ######################################################################### 100.0%
# ==> Fetching libtasn1
# ==> Downloading https://ghcr.io/v2/homebrew/core/libtasn1/blobs/sha256:975eaba8f
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/nettle/manifests/3.10
# ######################################################################### 100.0%
# ==> Fetching nettle
# ==> Downloading https://ghcr.io/v2/homebrew/core/nettle/blobs/sha256:79f26a53dfc
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/p11-kit/manifests/0.25.5
# ######################################################################### 100.0%
# ==> Fetching p11-kit
# ==> Downloading https://ghcr.io/v2/homebrew/core/p11-kit/blobs/sha256:0e51a00f26
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libevent/manifests/2.1.12_1
# ######################################################################### 100.0%
# ==> Fetching libevent
# ==> Downloading https://ghcr.io/v2/homebrew/core/libevent/blobs/sha256:38a3eb351
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libnghttp2/manifests/1.61.0
# ######################################################################### 100.0%
# ==> Fetching libnghttp2
# ==> Downloading https://ghcr.io/v2/homebrew/core/libnghttp2/blobs/sha256:6bd6cd9
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/unbound/manifests/1.20.0
# ######################################################################### 100.0%
# ==> Fetching unbound
# ==> Downloading https://ghcr.io/v2/homebrew/core/unbound/blobs/sha256:d747e30c1d
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/gnutls/manifests/3.8.4
# ######################################################################### 100.0%
# ==> Fetching gnutls
# ==> Downloading https://ghcr.io/v2/homebrew/core/gnutls/blobs/sha256:46373a7206c
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/python/3.12/manifests/3.12.4
# ######################################################################### 100.0%
# ==> Fetching python@3.12
# ==> Downloading https://ghcr.io/v2/homebrew/core/python/3.12/blobs/sha256:abcd74
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/glib/manifests/2.80.4
# ######################################################################### 100.0%
# ==> Fetching glib
# ==> Downloading https://ghcr.io/v2/homebrew/core/glib/blobs/sha256:e52c5b1cfc4a9
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/xorgproto/manifests/2024.1
# ######################################################################### 100.0%
# ==> Fetching xorgproto
# ==> Downloading https://ghcr.io/v2/homebrew/core/xorgproto/blobs/sha256:3307601f
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libxau/manifests/1.0.11
# ######################################################################### 100.0%
# ==> Fetching libxau
# ==> Downloading https://ghcr.io/v2/homebrew/core/libxau/blobs/sha256:5af5678065c
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libxdmcp/manifests/1.1.5
# ######################################################################### 100.0%
# ==> Fetching libxdmcp
# ==> Downloading https://ghcr.io/v2/homebrew/core/libxdmcp/blobs/sha256:789326aa8
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libxcb/manifests/1.17.0
# ######################################################################### 100.0%
# ==> Fetching libxcb
# ==> Downloading https://ghcr.io/v2/homebrew/core/libxcb/blobs/sha256:73d10366172
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libx11/manifests/1.8.10
# ######################################################################### 100.0%
# ==> Fetching libx11
# ==> Downloading https://ghcr.io/v2/homebrew/core/libx11/blobs/sha256:5467d415012
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libxext/manifests/1.3.6
# ######################################################################### 100.0%
# ==> Fetching libxext
# ==> Downloading https://ghcr.io/v2/homebrew/core/libxext/blobs/sha256:50a9b29c59
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libxrender/manifests/0.9.11
# ######################################################################### 100.0%
# ==> Fetching libxrender
# ==> Downloading https://ghcr.io/v2/homebrew/core/libxrender/blobs/sha256:3872611
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/lzo/manifests/2.10
# ######################################################################### 100.0%
# ==> Fetching lzo
# ==> Downloading https://ghcr.io/v2/homebrew/core/lzo/blobs/sha256:167749edd2052e
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/pixman/manifests/0.42.2-1
# ######################################################################### 100.0%
# ==> Fetching pixman
# ==> Downloading https://ghcr.io/v2/homebrew/core/pixman/blobs/sha256:d355a294d3f
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/cairo/manifests/1.18.0
# ######################################################################### 100.0%
# ==> Fetching cairo
# ==> Downloading https://ghcr.io/v2/homebrew/core/cairo/blobs/sha256:06c6aaadeca8
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/graphite2/manifests/1.3.14
# ######################################################################### 100.0%
# ==> Fetching graphite2
# ==> Downloading https://ghcr.io/v2/homebrew/core/graphite2/blobs/sha256:4cdee055
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/icu4c/manifests/74.2
# ######################################################################### 100.0%
# ==> Fetching icu4c
# ==> Downloading https://ghcr.io/v2/homebrew/core/icu4c/blobs/sha256:3facc22a7821
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/harfbuzz/manifests/9.0.0
# ######################################################################### 100.0%
# ==> Fetching harfbuzz
# ==> Downloading https://ghcr.io/v2/homebrew/core/harfbuzz/blobs/sha256:9b683aa2f
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/lame/manifests/3.100
# ######################################################################### 100.0%
# ==> Fetching lame
# ==> Downloading https://ghcr.io/v2/homebrew/core/lame/blobs/sha256:a5116a219d70f
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/fribidi/manifests/1.0.15
# ######################################################################### 100.0%
# ==> Fetching fribidi
# ==> Downloading https://ghcr.io/v2/homebrew/core/fribidi/blobs/sha256:b952c91e6e
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libunibreak/manifests/6.1
# ######################################################################### 100.0%
# ==> Fetching libunibreak
# ==> Downloading https://ghcr.io/v2/homebrew/core/libunibreak/blobs/sha256:687db5
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libass/manifests/0.17.3
# ######################################################################### 100.0%
# ==> Fetching libass
# ==> Downloading https://ghcr.io/v2/homebrew/core/libass/blobs/sha256:9e8889c7d43
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libbluray/manifests/1.3.4
# ######################################################################### 100.0%
# ==> Fetching libbluray
# ==> Downloading https://ghcr.io/v2/homebrew/core/libbluray/blobs/sha256:385b5460
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/cjson/manifests/1.7.18
# ######################################################################### 100.0%
# ==> Fetching cjson
# ==> Downloading https://ghcr.io/v2/homebrew/core/cjson/blobs/sha256:6deee0399f8b
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libmicrohttpd/manifests/1.0.1
# ######################################################################### 100.0%
# ==> Fetching libmicrohttpd
# ==> Downloading https://ghcr.io/v2/homebrew/core/libmicrohttpd/blobs/sha256:a787
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/mbedtls/manifests/3.6.0
# ######################################################################### 100.0%
# ==> Fetching mbedtls
# ==> Downloading https://ghcr.io/v2/homebrew/core/mbedtls/blobs/sha256:22f2f5791b
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/librist/manifests/0.2.10_1
# ######################################################################### 100.0%
# ==> Fetching librist
# ==> Downloading https://ghcr.io/v2/homebrew/core/librist/blobs/sha256:a008dc6bce
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libsoxr/manifests/0.1.3-1
# ######################################################################### 100.0%
# ==> Fetching libsoxr
# ==> Downloading https://ghcr.io/v2/homebrew/core/libsoxr/blobs/sha256:baddfdda71
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libssh/manifests/0.11.0
# ######################################################################### 100.0%
# ==> Fetching libssh
# ==> Downloading https://ghcr.io/v2/homebrew/core/libssh/blobs/sha256:a5f6829574f
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libvidstab/manifests/1.1.1
# ######################################################################### 100.0%
# ==> Fetching libvidstab
# ==> Downloading https://ghcr.io/v2/homebrew/core/libvidstab/blobs/sha256:f006d60
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libogg/manifests/1.3.5-2
# ######################################################################### 100.0%
# ==> Fetching libogg
# ==> Downloading https://ghcr.io/v2/homebrew/core/libogg/blobs/sha256:f5da0b4874b
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libvorbis/manifests/1.3.7-1
# ######################################################################### 100.0%
# ==> Fetching libvorbis
# ==> Downloading https://ghcr.io/v2/homebrew/core/libvorbis/blobs/sha256:f71115c2
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libvpx/manifests/1.13.1
# ######################################################################### 100.0%
# ==> Fetching libvpx
# ==> Downloading https://ghcr.io/v2/homebrew/core/libvpx/blobs/sha256:484698903af
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/opencore-amr/manifests/0.1.6
# ######################################################################### 100.0%
# ==> Fetching opencore-amr
# ==> Downloading https://ghcr.io/v2/homebrew/core/opencore-amr/blobs/sha256:b9598
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/openjpeg/manifests/2.5.2
# ######################################################################### 100.0%
# ==> Fetching openjpeg
# ==> Downloading https://ghcr.io/v2/homebrew/core/openjpeg/blobs/sha256:eef55952d
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/opus/manifests/1.5.2
# ######################################################################### 100.0%
# ==> Fetching opus
# ==> Downloading https://ghcr.io/v2/homebrew/core/opus/blobs/sha256:017d3d10cf679
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/rav1e/manifests/0.7.1
# ######################################################################### 100.0%
# ==> Fetching rav1e
# ==> Downloading https://ghcr.io/v2/homebrew/core/rav1e/blobs/sha256:03c3c20f83de
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libsamplerate/manifests/0.2.2
# ######################################################################### 100.0%
# ==> Fetching libsamplerate
# ==> Downloading https://ghcr.io/v2/homebrew/core/libsamplerate/blobs/sha256:dc27
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/flac/manifests/1.4.3
# ######################################################################### 100.0%
# ==> Fetching flac
# ==> Downloading https://ghcr.io/v2/homebrew/core/flac/blobs/sha256:ce19f4c9e89fb
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/mpg123/manifests/1.32.7
# ######################################################################### 100.0%
# ==> Fetching mpg123
# ==> Downloading https://ghcr.io/v2/homebrew/core/mpg123/blobs/sha256:5bbad58b97f
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libsndfile/manifests/1.2.2-2
# ######################################################################### 100.0%
# ==> Fetching libsndfile
# ==> Downloading https://ghcr.io/v2/homebrew/core/libsndfile/blobs/sha256:0e8ccf4
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/rubberband/manifests/3.3.0
# ######################################################################### 100.0%
# ==> Fetching rubberband
# ==> Downloading https://ghcr.io/v2/homebrew/core/rubberband/blobs/sha256:83e5b2a
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/sdl2/manifests/2.30.6
# ######################################################################### 100.0%
# ==> Fetching sdl2
# ==> Downloading https://ghcr.io/v2/homebrew/core/sdl2/blobs/sha256:c88013f3dacc2
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/snappy/manifests/1.2.1
# ######################################################################### 100.0%
# ==> Fetching snappy
# ==> Downloading https://ghcr.io/v2/homebrew/core/snappy/blobs/sha256:2b905dfed7d
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/speex/manifests/1.2.1
# ######################################################################### 100.0%
# ==> Fetching speex
# ==> Downloading https://ghcr.io/v2/homebrew/core/speex/blobs/sha256:8dcf1981467a
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/srt/manifests/1.5.3
# ######################################################################### 100.0%
# ==> Fetching srt
# ==> Downloading https://ghcr.io/v2/homebrew/core/srt/blobs/sha256:b77e98814ca5b9
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/svt-av1/manifests/2.1.2
# ######################################################################### 100.0%
# ==> Fetching svt-av1
# ==> Downloading https://ghcr.io/v2/homebrew/core/svt-av1/blobs/sha256:5b2187052d
# ###########################################                                59.8%^C

# %%
# %pip install numpy==1.23.1
# Out:
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# Collecting numpy==1.23.1
#   Downloading numpy-1.23.1-cp39-cp39-macosx_11_0_arm64.whl.metadata (2.2 kB)
# Downloading numpy-1.23.1-cp39-cp39-macosx_11_0_arm64.whl (13.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.3/13.3 MB 4.6 MB/s eta 0:00:0000:0100:01m
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.1
#     Uninstalling numpy-2.0.1:
#       Successfully uninstalled numpy-2.0.1
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# Successfully installed numpy-1.23.1
#
# [notice] A new release of pip is available: 24.1.2 -> 24.2
# [notice] To update, run: python3.9 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
print(np.__version__)
# Out:
# 1.23.1

# %%
# %pip install pyvirtualdisplay pyopengl
# Out:
# Collecting pyvirtualdisplay
#   Downloading PyVirtualDisplay-3.0-py3-none-any.whl.metadata (943 bytes)
# Collecting pyopengl
#   Downloading PyOpenGL-3.1.7-py3-none-any.whl.metadata (3.2 kB)
# Downloading PyVirtualDisplay-3.0-py3-none-any.whl (15 kB)
# Downloading PyOpenGL-3.1.7-py3-none-any.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 2.2 MB/s eta 0:00:00a 0:00:010m
# Installing collected packages: pyvirtualdisplay, pyopengl
# Successfully installed pyopengl-3.1.7 pyvirtualdisplay-3.0
#
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Importing the Required Libraries

# %%
from PIL import Image
import IPython.display as display
import gym
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from collections import deque
import random
import matplotlib.pyplot as plt
import time

# %% [markdown]
# ### Define DQN model

# %%
class DQN(nn.Module):
    def __init__(self, input_shape, num_actions):
        super(DQN, self).__init__()
        self.conv1 = nn.Conv2d(input_shape[0], 32, kernel_size=8, stride=4)
        self.conv2 = nn.Conv2d(32, 64, kernel_size=4, stride=2)
        self.conv3 = nn.Conv2d(64, 64, kernel_size=3, stride=1)
        self.fc1_input_dim = self.feature_size(input_shape)
        self.fc1 = nn.Linear(self.fc1_input_dim, 512)
        self.fc2 = nn.Linear(512, num_actions)

    def feature_size(self, input_shape):
        return self.conv3(self.conv2(self.conv1(torch.zeros(1, *input_shape)))).view(1, -1).size(1)

    def forward(self, x):
        x = F.relu(self.conv1(x))
        x = F.relu(self.conv2(x))
        x = F.relu(self.conv3(x))
        x = x.view(x.size(0), -1)
        x = F.relu(self.fc1(x))
        return self.fc2(x)

# %% [markdown]
# ### Define DQN model

# %%
class DQNAgent:
    def __init__(self, input_shape, num_actions):
        self.model = DQN(input_shape, num_actions)
        self.target_model = DQN(input_shape, num_actions)
        self.optimizer = optim.Adam(self.model.parameters(), lr=0.0001)
        self.replay_buffer = deque(maxlen=10000)
        self.batch_size = 32
        self.gamma = 0.99
        self.update_target_frequency = 1000
        self.steps = 0
        self.num_actions = num_actions

    def act(self, state, epsilon=0.1):
        if random.random() < epsilon:
            return random.randint(0, self.num_actions - 1)
        state = torch.FloatTensor(state).unsqueeze(0)
        q_values = self.model(state)
        return torch.argmax(q_values).item()

    def remember(self, state, action, reward, next_state, done):
        self.replay_buffer.append((state, action, reward, next_state, done))

    def train(self):
        if len(self.replay_buffer) < self.batch_size:
            return

        batch = random.sample(self.replay_buffer, self.batch_size)
        states, actions, rewards, next_states, dones = zip(*batch)

        states = torch.FloatTensor(np.array(states))
        actions = torch.LongTensor(actions).unsqueeze(1)
        rewards = torch.FloatTensor(rewards).unsqueeze(1)
        next_states = torch.FloatTensor(np.array(next_states))
        dones = torch.FloatTensor(dones).unsqueeze(1)

        current_q_values = self.model(states).gather(1, actions)
        next_q_values = self.target_model(next_states).max(1)[0].unsqueeze(1)
        target_q_values = rewards + (self.gamma * next_q_values * (1 - dones))

        loss = F.mse_loss(current_q_values, target_q_values)

        self.optimizer.zero_grad()
        loss.backward()
        self.optimizer.step()

        self.steps += 1
        if self.steps % self.update_target_frequency == 0:
            self.target_model.load_state_dict(self.model.state_dict())

# %% [markdown]
# ### Training function for DQN

# %%
def train_dqn(env_id, num_episodes=5):
    env = gym.make(env_id)
    input_shape = (3, 210, 160)
    num_actions = env.action_space.n

    dqn_agent = DQNAgent(input_shape, num_actions)

    epsilon_start = 1.0
    epsilon_end = 0.01
    epsilon_decay = 0.995
    epsilon = epsilon_start

    dqn_rewards = []

    for episode in range(num_episodes):
        state = env.reset()
        state = np.transpose(state, (2, 0, 1))  # Convert to channel-first format
        done = False
        total_reward = 0

        while not done:
            action = dqn_agent.act(state, epsilon)
            next_state, reward, done, _ = env.step(action)
            next_state = np.transpose(next_state, (2, 0, 1))  # Convert to channel-first format
            dqn_agent.remember(state, action, reward, next_state, done)
            dqn_agent.train()
            state = next_state
            total_reward += reward

        epsilon = max(epsilon_end, epsilon_decay * epsilon)
        dqn_rewards.append(total_reward)
        print(f"Episode: {episode + 1}, Reward: {total_reward}, Epsilon: {epsilon:.2f}")

    return dqn_agent, dqn_rewards

# %% [markdown]
# ### Training the DQN Agent

# %%
env_id = 'MsPacman-v4'
num_episodes = 100

print("Training DQN Agent...")
dqn_agent, dqn_rewards = train_dqn(env_id, num_episodes=num_episodes)
print("DQN Training completed.")
# Out:
# Training DQN Agent...
# Episode: 1, Reward: 220.0, Epsilon: 0.99
# Episode: 2, Reward: 250.0, Epsilon: 0.99
# Episode: 3, Reward: 160.0, Epsilon: 0.99
# Episode: 4, Reward: 170.0, Epsilon: 0.98
# Episode: 5, Reward: 150.0, Epsilon: 0.98
# Episode: 6, Reward: 270.0, Epsilon: 0.97
# Episode: 7, Reward: 290.0, Epsilon: 0.97
# Episode: 8, Reward: 290.0, Epsilon: 0.96
# Episode: 9, Reward: 560.0, Epsilon: 0.96
# Episode: 10, Reward: 220.0, Epsilon: 0.95
# Episode: 11, Reward: 330.0, Epsilon: 0.95
# Episode: 12, Reward: 210.0, Epsilon: 0.94
# Episode: 13, Reward: 200.0, Epsilon: 0.94
# Episode: 14, Reward: 180.0, Epsilon: 0.93
# Episode: 15, Reward: 190.0, Epsilon: 0.93
# Episode: 16, Reward: 230.0, Epsilon: 0.92
# Episode: 17, Reward: 140.0, Epsilon: 0.92
# Episode: 18, Reward: 230.0, Epsilon: 0.91
# Episode: 19, Reward: 190.0, Epsilon: 0.91
# Episode: 20, Reward: 210.0, Epsilon: 0.90
# Episode: 21, Reward: 620.0, Epsilon: 0.90
# Episode: 22, Reward: 330.0, Epsilon: 0.90
# Episode: 23, Reward: 290.0, Epsilon: 0.89
# Episode: 24, Reward: 120.0, Epsilon: 0.89
# Episode: 25, Reward: 210.0, Epsilon: 0.88
# Episode: 26, Reward: 250.0, Epsilon: 0.88
# Episode: 27, Reward: 180.0, Epsilon: 0.87
# Episode: 28, Reward: 240.0, Epsilon: 0.87
# Episode: 29, Reward: 180.0, Epsilon: 0.86
# Episode: 30, Reward: 490.0, Epsilon: 0.86
# Episode: 31, Reward: 300.0, Epsilon: 0.86
# Episode: 32, Reward: 200.0, Epsilon: 0.85
# Episode: 33, Reward: 200.0, Epsilon: 0.85
# Episode: 34, Reward: 240.0, Epsilon: 0.84
# Episode: 35, Reward: 240.0, Epsilon: 0.84
# Episode: 36, Reward: 250.0, Epsilon: 0.83
# Episode: 37, Reward: 180.0, Epsilon: 0.83
# Episode: 38, Reward: 190.0, Epsilon: 0.83
# Episode: 39, Reward: 220.0, Epsilon: 0.82
# Episode: 40, Reward: 190.0, Epsilon: 0.82
# Episode: 41, Reward: 170.0, Epsilon: 0.81
# Episode: 42, Reward: 290.0, Epsilon: 0.81
# Episode: 43, Reward: 330.0, Epsilon: 0.81
# Episode: 44, Reward: 350.0, Epsilon: 0.80
# Episode: 45, Reward: 90.0, Epsilon: 0.80
# Episode: 46, Reward: 230.0, Epsilon: 0.79
# Episode: 47, Reward: 580.0, Epsilon: 0.79
# Episode: 48, Reward: 180.0, Epsilon: 0.79
# Episode: 49, Reward: 290.0, Epsilon: 0.78
# Episode: 50, Reward: 230.0, Epsilon: 0.78
# Episode: 51, Reward: 170.0, Epsilon: 0.77
# Episode: 52, Reward: 200.0, Epsilon: 0.77
# Episode: 53, Reward: 270.0, Epsilon: 0.77
# Episode: 54, Reward: 280.0, Epsilon: 0.76
# Episode: 55, Reward: 180.0, Epsilon: 0.76
# Episode: 56, Reward: 270.0, Epsilon: 0.76
# Episode: 57, Reward: 250.0, Epsilon: 0.75
# Episode: 58, Reward: 290.0, Epsilon: 0.75
# Episode: 59, Reward: 260.0, Epsilon: 0.74
# Episode: 60, Reward: 250.0, Epsilon: 0.74
# Episode: 61, Reward: 520.0, Epsilon: 0.74
# Episode: 62, Reward: 210.0, Epsilon: 0.73
# Episode: 63, Reward: 200.0, Epsilon: 0.73
# Episode: 64, Reward: 290.0, Epsilon: 0.73
# Episode: 65, Reward: 310.0, Epsilon: 0.72
# Episode: 66, Reward: 640.0, Epsilon: 0.72
# Episode: 67, Reward: 260.0, Epsilon: 0.71
# Episode: 68, Reward: 290.0, Epsilon: 0.71
# Episode: 69, Reward: 120.0, Epsilon: 0.71
# Episode: 70, Reward: 660.0, Epsilon: 0.70
# Episode: 71, Reward: 210.0, Epsilon: 0.70
# Episode: 72, Reward: 230.0, Epsilon: 0.70
# Episode: 73, Reward: 330.0, Epsilon: 0.69
# Episode: 74, Reward: 150.0, Epsilon: 0.69
# Episode: 75, Reward: 250.0, Epsilon: 0.69
# Episode: 76, Reward: 440.0, Epsilon: 0.68
# Episode: 77, Reward: 320.0, Epsilon: 0.68
# Episode: 78, Reward: 260.0, Epsilon: 0.68
# Episode: 79, Reward: 130.0, Epsilon: 0.67
# Episode: 80, Reward: 260.0, Epsilon: 0.67
# Episode: 81, Reward: 310.0, Epsilon: 0.67
# Episode: 82, Reward: 230.0, Epsilon: 0.66
# Episode: 83, Reward: 310.0, Epsilon: 0.66
# Episode: 84, Reward: 220.0, Epsilon: 0.66
# Episode: 85, Reward: 300.0, Epsilon: 0.65
# Episode: 86, Reward: 290.0, Epsilon: 0.65
# Episode: 87, Reward: 460.0, Epsilon: 0.65
# Episode: 88, Reward: 250.0, Epsilon: 0.64
# Episode: 89, Reward: 170.0, Epsilon: 0.64
# Episode: 90, Reward: 230.0, Epsilon: 0.64
# Episode: 91, Reward: 350.0, Epsilon: 0.63
# Episode: 92, Reward: 310.0, Epsilon: 0.63
# Episode: 93, Reward: 250.0, Epsilon: 0.63
# Episode: 94, Reward: 580.0, Epsilon: 0.62
# Episode: 95, Reward: 230.0, Epsilon: 0.62
# Episode: 96, Reward: 290.0, Epsilon: 0.62
# Episode: 97, Reward: 210.0, Epsilon: 0.61
# Episode: 98, Reward: 250.0, Epsilon: 0.61
# Episode: 99, Reward: 180.0, Epsilon: 0.61
# Episode: 100, Reward: 430.0, Epsilon: 0.61
# DQN Training completed.

# %% [markdown]
# ### Define Policy Network for PPO

# %%
class PolicyNetwork(nn.Module):
    def __init__(self, action_space):
        super(PolicyNetwork, self).__init__()
        self.conv1 = nn.Conv2d(3, 32, kernel_size=8, stride=4)
        self.conv2 = nn.Conv2d(32, 64, kernel_size=4, stride=2)
        self.conv3 = nn.Conv2d(64, 64, kernel_size=3, stride=1)
        self.fc1_input_dim = self.feature_size((3, 210, 160))  # Calculate input size to fc1
        self.fc1 = nn.Linear(self.fc1_input_dim, 512)
        self.mean = nn.Linear(512, action_space)
        self.std = nn.Linear(512, action_space)

    def feature_size(self, input_shape):
        x = torch.zeros(1, *input_shape)
        x = self.conv1(x)
        x = self.conv2(x)
        x = self.conv3(x)
        return x.view(1, -1).size(1)

    def forward(self, x):
        x = F.relu(self.conv1(x))
        x = F.relu(self.conv2(x))
        x = F.relu(self.conv3(x))
        x = x.view(x.size(0), -1)  # Flatten the tensor
        x = F.relu(self.fc1(x))
        mean = self.mean(x)
        std = torch.clamp(self.std(x), min=-20, max=2)
        return mean, std.exp()

# %% [markdown]
# ### Preprocess state function for PPO

# %%
def preprocess_state(state):
    state = torch.tensor(state, dtype=torch.float32).permute(2, 0, 1)  # Transpose to [channels, height, width]
    return state.unsqueeze(0)  # Add batch dimension

# %% [markdown]
# ### Training function for PPO

# %%
def train_ppo(env_name, max_episodes, max_steps_per_episode, lr, gamma, clip_ratio, epochs):
    env = gym.make(env_name)
    state_dim = env.observation_space.shape
    action_dim = env.action_space.n
    policy_net = PolicyNetwork(action_dim)
    optimizer = optim.Adam(policy_net.parameters(), lr=lr)

    ppo_rewards = []

    for episode in range(1, max_episodes + 1):
        state = preprocess_state(env.reset())
        episode_rewards = 0

        for step in range(max_steps_per_episode):
            with torch.no_grad():
                mean, std = policy_net(state)
                dist = torch.distributions.Normal(mean, std)
                action = dist.sample()
                log_prob = dist.log_prob(action).sum()

            next_state, reward, done, _ = env.step(action.argmax().item())
            next_state = preprocess_state(next_state)
            episode_rewards += reward

            state = next_state

        ppo_rewards.append(episode_rewards)
        print(f"Episode {episode}:  Reward = {episode_rewards}")

    return policy_net, ppo_rewards

# %% [markdown]
# ### Function to plot rewards for DQN

# %%
import matplotlib.pyplot as plt
import numpy as np


def plot_dqn_rewards(dqn_rewards):
    def moving_average(data, window_size):
        return np.convolve(data, np.ones(window_size) / window_size, mode='valid')

    dqn_smoothed_rewards = moving_average(dqn_rewards, window_size=3)

    plt.figure(figsize=(12, 6))
    plt.plot(dqn_rewards, label='DQN (Original)', color='skyblue', alpha=0.5, linestyle='--')
    plt.plot(dqn_smoothed_rewards, label='DQN (Smoothed)', color='blue', linewidth=2)
    plt.xlabel('Episode', fontsize=14)
    plt.ylabel('Total Reward', fontsize=14)
    plt.title('DQN Training Rewards', fontsize=16)
    plt.legend(fontsize=12)
    plt.grid(True, linestyle='--', alpha=0.7)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### Function to plot rewards for PPO

# %%
def plot_ppo_rewards(ppo_rewards):
    def moving_average(data, window_size):
        return np.convolve(data, np.ones(window_size) / window_size, mode='valid')

    ppo_smoothed_rewards = moving_average(ppo_rewards, window_size=3)

    plt.figure(figsize=(12, 6))
    plt.plot(ppo_rewards, label='PPO (Original)', color='lightgreen', alpha=0.5, linestyle='--')
    plt.plot(ppo_smoothed_rewards, label='PPO (Smoothed)', color='green', linewidth=2)
    plt.xlabel('Episode', fontsize=14)
    plt.ylabel('Total Reward', fontsize=14)
    plt.title('PPO Training Rewards', fontsize=16)
    plt.legend(fontsize=12)
    plt.grid(True, linestyle='--', alpha=0.7)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### Display DQN Game Window

# %%
def display_game_dqn(env_id, agent):
    env = gym.make(env_id, render_mode='rgb_array')
    state = env.reset()
    state = np.transpose(state, (2, 0, 1))  # Convert to channel-first format
    done = False
    frames = []

    while not done:
        action = agent.act(state, epsilon=0.0)  # Use the trained agent for actions
        next_state, reward, done, _ = env.step(action)
        next_state = np.transpose(next_state, (2, 0, 1))  # Convert to channel-first format
        state = next_state
        frames.append(env.render(mode='rgb_array'))
        time.sleep(0.05)

    env.close()

    # Display frames as an animation
    for frame in frames:
        img = Image.fromarray(frame)
        display.display(img)
        display.clear_output(wait=True)

# %%
### Display PPO Game Window

# %%
def display_game_ppo(env_id, agent):
    env = gym.make(env_id, render_mode='rgb_array')
    state = preprocess_state(env.reset())
    done = False
    frames = []

    while not done:
        with torch.no_grad():
            mean, std = agent(state)
            dist = torch.distributions.Normal(mean, std)
            action = dist.sample()

        next_state, reward, done, _ = env.step(action.argmax().item())
        next_state = preprocess_state(next_state)
        state = next_state
        frames.append(env.render(mode='rgb_array'))
        time.sleep(0.05)

    env.close()

    # Display frames as an animation
    for frame in frames:
        img = Image.fromarray(frame)
        display.display(img)
        display.clear_output(wait=True)

# %% [markdown]
# ### Training PPO Agent

# %%
print("Training PPO Agent...")
max_episodes = 250
max_steps_per_episode = 200
lr = 1e-3
gamma = 0.99
clip_ratio = 0.2
epochs = 10
ppo_agent, ppo_rewards = train_ppo(env_id, max_episodes, max_steps_per_episode, lr, gamma, clip_ratio, epochs)
print("PPO Training completed.")
# Out:
# Training PPO Agent...
# Episode 1:  Reward = 100.0
# Episode 2:  Reward = 100.0
# Episode 3:  Reward = 130.0
# Episode 4:  Reward = 130.0
# Episode 5:  Reward = 60.0
# Episode 6:  Reward = 80.0
# Episode 7:  Reward = 70.0
# Episode 8:  Reward = 100.0
# Episode 9:  Reward = 90.0
# Episode 10:  Reward = 190.0
# Episode 11:  Reward = 210.0
# Episode 12:  Reward = 130.0
# Episode 13:  Reward = 190.0
# Episode 14:  Reward = 140.0
# Episode 15:  Reward = 140.0
# Episode 16:  Reward = 130.0
# Episode 17:  Reward = 100.0
# Episode 18:  Reward = 80.0
# Episode 19:  Reward = 80.0
# Episode 20:  Reward = 90.0
# Episode 21:  Reward = 190.0
# Episode 22:  Reward = 140.0
# Episode 23:  Reward = 190.0
# Episode 24:  Reward = 150.0
# Episode 25:  Reward = 190.0
# Episode 26:  Reward = 80.0
# Episode 27:  Reward = 110.0
# Episode 28:  Reward = 90.0
# Episode 29:  Reward = 80.0
# Episode 30:  Reward = 80.0
# Episode 31:  Reward = 90.0
# Episode 32:  Reward = 80.0
# Episode 33:  Reward = 90.0
# Episode 34:  Reward = 180.0
# Episode 35:  Reward = 90.0
# Episode 36:  Reward = 200.0
# Episode 37:  Reward = 170.0
# Episode 38:  Reward = 90.0
# Episode 39:  Reward = 160.0
# Episode 40:  Reward = 180.0
# Episode 41:  Reward = 130.0
# Episode 42:  Reward = 100.0
# Episode 43:  Reward = 150.0
# Episode 44:  Reward = 80.0
# Episode 45:  Reward = 80.0
# Episode 46:  Reward = 110.0
# Episode 47:  Reward = 140.0
# Episode 48:  Reward = 140.0
# Episode 49:  Reward = 130.0
# Episode 50:  Reward = 210.0
# Episode 51:  Reward = 80.0
# Episode 52:  Reward = 90.0
# Episode 53:  Reward = 80.0
# Episode 54:  Reward = 80.0
# Episode 55:  Reward = 130.0
# Episode 56:  Reward = 80.0
# Episode 57:  Reward = 90.0
# Episode 58:  Reward = 90.0
# Episode 59:  Reward = 80.0
# Episode 60:  Reward = 90.0
# Episode 61:  Reward = 150.0
# Episode 62:  Reward = 80.0
# Episode 63:  Reward = 80.0
# Episode 64:  Reward = 140.0
# Episode 65:  Reward = 190.0
# Episode 66:  Reward = 140.0
# Episode 67:  Reward = 70.0
# Episode 68:  Reward = 120.0
# Episode 69:  Reward = 140.0
# Episode 70:  Reward = 90.0
# Episode 71:  Reward = 160.0
# Episode 72:  Reward = 80.0
# Episode 73:  Reward = 140.0
# Episode 74:  Reward = 70.0
# Episode 75:  Reward = 100.0
# Episode 76:  Reward = 140.0
# Episode 77:  Reward = 180.0
# Episode 78:  Reward = 110.0
# Episode 79:  Reward = 80.0
# Episode 80:  Reward = 160.0
# Episode 81:  Reward = 190.0
# Episode 82:  Reward = 140.0
# Episode 83:  Reward = 180.0
# Episode 84:  Reward = 80.0
# Episode 85:  Reward = 180.0
# Episode 86:  Reward = 150.0
# Episode 87:  Reward = 90.0
# Episode 88:  Reward = 100.0
# Episode 89:  Reward = 160.0
# Episode 90:  Reward = 80.0
# Episode 91:  Reward = 130.0
# Episode 92:  Reward = 80.0
# Episode 93:  Reward = 100.0
# Episode 94:  Reward = 160.0
# Episode 95:  Reward = 140.0
# Episode 96:  Reward = 80.0
# Episode 97:  Reward = 200.0
# Episode 98:  Reward = 190.0
# Episode 99:  Reward = 100.0
# Episode 100:  Reward = 190.0
# Episode 101:  Reward = 70.0
# Episode 102:  Reward = 140.0
# Episode 103:  Reward = 200.0
# Episode 104:  Reward = 100.0
# Episode 105:  Reward = 140.0
# Episode 106:  Reward = 90.0
# Episode 107:  Reward = 190.0
# Episode 108:  Reward = 140.0
# Episode 109:  Reward = 80.0
# Episode 110:  Reward = 90.0
# Episode 111:  Reward = 180.0
# Episode 112:  Reward = 150.0
# Episode 113:  Reward = 90.0
# Episode 114:  Reward = 120.0
# Episode 115:  Reward = 150.0
# Episode 116:  Reward = 230.0
# Episode 117:  Reward = 80.0
# Episode 118:  Reward = 190.0
# Episode 119:  Reward = 90.0
# Episode 120:  Reward = 80.0
# Episode 121:  Reward = 80.0
# Episode 122:  Reward = 80.0
# Episode 123:  Reward = 140.0
# Episode 124:  Reward = 90.0
# Episode 125:  Reward = 80.0
# Episode 126:  Reward = 130.0
# Episode 127:  Reward = 190.0
# Episode 128:  Reward = 190.0
# Episode 129:  Reward = 80.0
# Episode 130:  Reward = 190.0
# Episode 131:  Reward = 190.0
# Episode 132:  Reward = 170.0
# Episode 133:  Reward = 120.0
# Episode 134:  Reward = 110.0
# Episode 135:  Reward = 130.0
# Episode 136:  Reward = 90.0
# Episode 137:  Reward = 190.0
# Episode 138:  Reward = 80.0
# Episode 139:  Reward = 130.0
# Episode 140:  Reward = 110.0
# Episode 141:  Reward = 120.0
# Episode 142:  Reward = 190.0
# Episode 143:  Reward = 140.0
# Episode 144:  Reward = 80.0
# Episode 145:  Reward = 190.0
# Episode 146:  Reward = 80.0
# Episode 147:  Reward = 150.0
# Episode 148:  Reward = 180.0
# Episode 149:  Reward = 90.0
# Episode 150:  Reward = 190.0
# Episode 151:  Reward = 120.0
# Episode 152:  Reward = 150.0
# Episode 153:  Reward = 130.0
# Episode 154:  Reward = 110.0
# Episode 155:  Reward = 200.0
# Episode 156:  Reward = 150.0
# Episode 157:  Reward = 190.0
# Episode 158:  Reward = 120.0
# Episode 159:  Reward = 90.0
# Episode 160:  Reward = 80.0
# Episode 161:  Reward = 90.0
# Episode 162:  Reward = 160.0
# Episode 163:  Reward = 80.0
# Episode 164:  Reward = 70.0
# Episode 165:  Reward = 70.0
# Episode 166:  Reward = 120.0
# Episode 167:  Reward = 100.0
# Episode 168:  Reward = 80.0
# Episode 169:  Reward = 130.0
# Episode 170:  Reward = 80.0
# Episode 171:  Reward = 190.0
# Episode 172:  Reward = 80.0
# Episode 173:  Reward = 200.0
# Episode 174:  Reward = 140.0
# Episode 175:  Reward = 90.0
# Episode 176:  Reward = 200.0
# Episode 177:  Reward = 150.0
# Episode 178:  Reward = 140.0
# Episode 179:  Reward = 90.0
# Episode 180:  Reward = 70.0
# Episode 181:  Reward = 120.0
# Episode 182:  Reward = 100.0
# Episode 183:  Reward = 200.0
# Episode 184:  Reward = 200.0
# Episode 185:  Reward = 140.0
# Episode 186:  Reward = 90.0
# Episode 187:  Reward = 80.0
# Episode 188:  Reward = 210.0
# Episode 189:  Reward = 100.0
# Episode 190:  Reward = 80.0
# Episode 191:  Reward = 70.0
# Episode 192:  Reward = 120.0
# Episode 193:  Reward = 70.0
# Episode 194:  Reward = 80.0
# Episode 195:  Reward = 70.0
# Episode 196:  Reward = 130.0
# Episode 197:  Reward = 150.0
# Episode 198:  Reward = 140.0
# Episode 199:  Reward = 190.0
# Episode 200:  Reward = 130.0
# Episode 201:  Reward = 190.0
# Episode 202:  Reward = 150.0
# Episode 203:  Reward = 40.0
# Episode 204:  Reward = 80.0
# Episode 205:  Reward = 110.0
# Episode 206:  Reward = 190.0
# Episode 207:  Reward = 190.0
# Episode 208:  Reward = 200.0
# Episode 209:  Reward = 90.0
# Episode 210:  Reward = 200.0
# Episode 211:  Reward = 170.0
# Episode 212:  Reward = 180.0
# Episode 213:  Reward = 80.0
# Episode 214:  Reward = 140.0
# Episode 215:  Reward = 90.0
# Episode 216:  Reward = 190.0
# Episode 217:  Reward = 70.0
# Episode 218:  Reward = 90.0
# Episode 219:  Reward = 100.0
# Episode 220:  Reward = 190.0
# Episode 221:  Reward = 190.0
# Episode 222:  Reward = 180.0
# Episode 223:  Reward = 190.0
# Episode 224:  Reward = 90.0
# Episode 225:  Reward = 110.0
# Episode 226:  Reward = 180.0
# Episode 227:  Reward = 200.0
# Episode 228:  Reward = 90.0
# Episode 229:  Reward = 140.0
# Episode 230:  Reward = 90.0
# Episode 231:  Reward = 140.0
# Episode 232:  Reward = 140.0
# Episode 233:  Reward = 190.0
# Episode 234:  Reward = 180.0
# Episode 235:  Reward = 100.0
# Episode 236:  Reward = 210.0
# Episode 237:  Reward = 70.0
# Episode 238:  Reward = 110.0
# Episode 239:  Reward = 140.0
# Episode 240:  Reward = 70.0
# Episode 241:  Reward = 170.0
# Episode 242:  Reward = 190.0
# Episode 243:  Reward = 80.0
# Episode 244:  Reward = 150.0
# Episode 245:  Reward = 150.0
# Episode 246:  Reward = 90.0
# Episode 247:  Reward = 190.0
# Episode 248:  Reward = 40.0
# Episode 249:  Reward = 190.0
# Episode 250:  Reward = 180.0
# PPO Training completed.

# %%
print("Plotting DQN rewards...")
plot_dqn_rewards(dqn_rewards)
# Out:
# Plotting DQN rewards...

# %%
print("Plotting DQN rewards...")
plot_ppo_rewards(ppo_rewards)
# Out:
# Plotting DQN rewards...

# %%
print("Rendering game using trained DQN agent...")
display_game_dqn(env_id, dqn_agent)
# Out:
# <PIL.Image.Image image mode=RGB size=160x210>

# %%
print("Rendering game using trained PPO agent...")
display_game_ppo(env_id, ppo_agent)
# Out:
# <PIL.Image.Image image mode=RGB size=160x210>

# %% [markdown]
# #### Comparison:
# * By comparing the DQN and PPO reward plots, you can evaluate the relative performance of both algorithms. Look for differences in the reward trends, stability, and overall performance to determine which algorithm provides better results for the given environment.

# %% [markdown]
# #### Conclusion & Future Work
#  * The project effectively demonstrated the application of DQN and PPO to train a Pac-Man agent, with PPO showing more stable performance compared to DQN. This indicates that PPO may be better suited for environments requiring consistent learning. Future work should focus on exploring advanced variations of DQN, performing extensive hyperparameter tuning, and testing the agent in more complex environments. Additionally, implementing real-time adaptation and developing better visualization tools will further enhance the agent's performance and analysis capabilities.
